# %%
import pandas

# %%
import numpy

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plot

# %%
import pandas as pd

# Verify the correct file path
file_path = "/content/archive (1).zip"  # Adjust if necessary

# Attempt to read the zip file
try:
    df = pd.read_csv(file_path)
    print(df.head())  # Print first few rows to check if loaded correctly
except FileNotFoundError:
    print(f"Error: File not found at '{file_path}'. Please check the file path and ensure the file exists.")
# Out:
# Error: File not found at '/content/archive (1).zip'. Please check the file path and ensure the file exists.

# %%
df = pandas.read_csv('/content/movies[1].csv')

# %%
print(df)

# %%
df . head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
from string import punctuation
# let see missing data
for col in df.columns:
  pct_missing = numpy.mean(df[col].isnull())
  print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
 # data types for this coloums
df. dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data types of colum
df['budget'] = df['budget'].astype('Int64')
df['gross'] = df['gross'].astype('Int64')
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0)
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['gross'] = pd.to_numeric(df['gross'], errors='coerce')

# %%
df

# %%
df['yearcorrect'] = df['released'].astype(str).str[:4]
df
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
pd.set_option('display.max_rows',None)

# %%
#drop any duplicat vales
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 6412                             iDeal Partners Film Fund
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 524                             Zupnik-Curtis Enterprises
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 6222                        Zentropa International Norway
# 3368                              Zentropa Entertainments
# 535                                  Zenith Entertainment
# 5180                                      Zazen Produções
# 3193                                          ZapPictures
# ...

# %%
# company high correltion
#buget high correltion
# scatter plot with budget vs gross
plot.scatter(x=df['budget'],y=df['gross'])
plot.title('Budget vs Gross Earnings')
plot.xlabel('Gross Earnings')

plot.ylabel('Budget for Film')
plot.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#plot budjet vs gross using
sns.regplot(x='budget',y='gross',data=df,scatter_kws={'color':'black'},line_kws={'color':'blue'})

# %%
# let see start looking at correation
